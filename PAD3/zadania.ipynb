# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('PAD_03_PD.csv',sep=';')
df
# Out:
#       ID Country  owns_car  owns_TV  owns_house  owns_Phone gender  Age
# 0      1       A       0.0      0.0         0.0           1      M   61
# 1      2       B       0.0      0.0         0.0           1      M   44
# 2      3       A       0.0      0.0         0.0           1      M   56
# 3      4       A       0.0      0.0         0.0           1      M   53
# 4      5       C       1.0      1.0         0.0           1      K   60
# ..   ...     ...       ...      ...         ...         ...    ...  ...
# 795  796       B       0.0      0.0         0.0           1      K   28
# 796  797       B       0.0      0.0         0.0           1      M   26
# 797  798       A       0.0      0.0         0.0           1      M   61
# 798  799       B       0.0      1.0         0.0           1      K   47
# 799  800       B       0.0      1.0         0.0           1      K   51
#
# [800 rows x 8 columns]

# %%
###ZAD1###
print(df.Country.value_counts())
# Out:
# A    328
# B    201
# C    186
# D     78
# Name: Country, dtype: int64

# %%
###ZAD2###
df['owned_goods']=df['owns_car']+df['owns_TV']+df['owns_house']+df['owns_Phone']
df
# Out:
#       ID Country  owns_car  owns_TV  owns_house  owns_Phone gender  Age  \
# 0      1       A       0.0      0.0         0.0           1      M   61
# 1      2       B       0.0      0.0         0.0           1      M   44
# 2      3       A       0.0      0.0         0.0           1      M   56
# 3      4       A       0.0      0.0         0.0           1      M   53
# 4      5       C       1.0      1.0         0.0           1      K   60
# ..   ...     ...       ...      ...         ...         ...    ...  ...
# 795  796       B       0.0      0.0         0.0           1      K   28
# 796  797       B       0.0      0.0         0.0           1      M   26
# 797  798       A       0.0      0.0         0.0           1      M   61
# 798  799       B       0.0      1.0         0.0           1      K   47
# 799  800       B       0.0      1.0         0.0           1      K   51
#
#      owned_goods
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# ...

# %%
###ZAD3###
round(df.groupby('gender')['owned_goods'].agg(['mean']),2)
# Out:
#         mean
# gender
# K       2.80
# M       0.89

# %%
###ZAD4###
df4_1= round(df.groupby('Country',as_index=False)['owned_goods'].agg(['mean']),2) ###coś nie działa -> powinno Country być kolumną / as_index = false
df4_2= df.groupby('Country')['Age'].agg(['min'])
df4_1['min']=df4_2['min']
df4_1
# Out:
#          mean  min
# Country
# A        0.86   18
# B        1.46   18
# C        3.03   18
# D        4.00   18
